# %% [markdown]
# # CW1 - Multimodal IMDB Analysis with Keras
#
# ## Introduction
#
# In this assignment you will be provided a dataset containing a selection of films together with their posters in JPEG image format and their overviews in text format from the Internet Movie Database.
#
# ![Example](https://i.ibb.co/J3trT62/Screenshot-2024-09-22-214753.png)
#
# You will be analysing this dataset by implementing and training two models: a **CNN** and an **LSTM**.
#
# The CNN must classify film posters by the genre. Independently, the LSTM must classify film overviews by the genre. Finally, you will evaluate and critically comment your results in a short report. (Which of the two models was better at classifying films?)
#
# ## Structure of the assignment
#
# This assignment is broken up into sections and you need to complete each section successively. The sections are the following:
#
# 1. Data Processing
#
#   1.a. Image processing of the posters
#
#   1.b. Natural language processing of the overviews
#
# 2. Definition of the models
#
#   2.a. CNN for the posters
#
#   2.b. LSTM for the overviews
#
# 3. Training of the models
# 4. Evaluation of the models
#
# In addition to this coding exercise, you must write a **2-3 pages** report analysing and critically evaluating your model's results. Marks for the report will be awarded for depth of analysis and critical thinking skills. You should consider how well your model performs and WHY it does that—give specific examples and comment on their importance.

# %%
# Enter your module imports here, some modules are already provided

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
import os
import pathlib
import pandas as pd
from sklearn import model_selection
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from keras.metrics import Precision, Recall
from tensorflow.keras.layers import Input, Conv2D, Dropout, MaxPooling2D, Flatten, Dense

# %%
# CodeGrade Tag Init1
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 1. Data Processing
#
# Warning: running the following cell can take some time.

# %%
# CodeGrade Tag Init2
# Do not edit, remove, or copy this cell

# This code will copy the images from your google drive into the colab file
# storage. Make sure the dataset is unzipped in your drive folder.
! mkdir /tmp/Multimodal_IMDB_dataset
! rsync -ah --info=progress2 /content/drive/MyDrive/Multimodal_IMDB_dataset/Images /tmp/Multimodal_IMDB_dataset/
# Out:
#         191.65M 100%    1.18MB/s    0:02:34 (xfr#7896, to-chk=0/7897)

# %%
# CodeGrade Tag Init3
# Do not edit, remove, or copy this cell

# Load the csv with the sample IDs and genres
csv_loc = "/content/drive/MyDrive/Multimodal_IMDB_dataset/IMDB_overview_genres.csv"
dataset = pd.read_csv(csv_loc)

# Split the dataset into training and testing
data_train, data_test = model_selection.train_test_split(dataset, test_size=0.2)

# Convert the labels to arrays
labels_train = np.array(data_train.drop(['Id', 'Genre', 'Overview'],axis=1)).astype('float32')
labels_test = np.array(data_test.drop(['Id', 'Genre', 'Overview'],axis=1)).astype('float32')

# List of the genre names
genres = np.array(data_train.drop(['Id', 'Genre', 'Overview'],axis=1).columns)

# List of overviews
overviews_train = np.array(data_train['Overview'])
overviews_test = np.array(data_test['Overview'])

# Build the file locations for the images
img_loc = "/tmp/Multimodal_IMDB_dataset/Images"

img_locs_train = np.array([[img_loc + '/' + id + '.jpg' for id in data_train['Id']]])
img_locs_test = [[img_loc + '/' + id + '.jpg' for id in data_test['Id']]]

# This function is provided to read in the image files from the folder
def parse_image(filename, label):
  image = tf.io.read_file(filename)
  image = tf.io.decode_jpeg(image)
  return image, label

# %% [markdown]
# ### 1.a. Image processing of the posters

# %%
# CodeGrade Tag Init4
# Do not edit, remove, or copy this cell

# Create the initial datasets of film posters
list_posters_train_ds = tf.data.Dataset.from_tensor_slices((img_locs_train[0], labels_train))
list_posters_valid_ds = tf.data.Dataset.from_tensor_slices((img_locs_test[0], labels_test))

# %% [markdown]
# * Create a function called ```img_process``` that converts the images to float32 datatype and resizes them to 64x64 pixels

# %%
# CodeGrade Tag Ex1a-i
### Create a function called img_process that converts the images to
### float32 datatype and resizes them to 64x64 pixels

def img_process(image, label):

    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, [64, 64])

    return image, label

# %% [markdown]
# * **Using the ``tf.data`` API, load in the training and validation data for the posters. Be mindful of efficient data processing good practice to minimise the time it takes to load the data.**

# %%
# CodeGrade Tag Ex1a-ii
### Use the parse_image and img_process functions to construct the training and
### validation datasets. You should utilise good practice in optimising the
### dataset loading. Use a batch size of 64.

BATCH_SIZE = 64
AUTOTUNE = tf.data.AUTOTUNE

posters_train_ds = (
    list_posters_train_ds
    .map(parse_image, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .map(img_process, num_parallel_calls=AUTOTUNE)
    .cache()
    .shuffle(1000)
    .prefetch(AUTOTUNE)
)

posters_valid_ds = (
    list_posters_valid_ds
    .map(parse_image, num_parallel_calls=AUTOTUNE)
    .batch(BATCH_SIZE)
    .map(img_process, num_parallel_calls=AUTOTUNE)
    .cache()
    .prefetch(AUTOTUNE)
)

# %% [markdown]
# ### 1.b. Natural Language processing of the overviews

# %%
# CodeGrade Tag Init5
# Do not edit, remove, or copy this cell

# Create the initial datasets of the film overviews
list_overviews_train_ds = tf.data.Dataset.from_tensor_slices((overviews_train, labels_train))
list_overviews_valid_ds = tf.data.Dataset.from_tensor_slices((overviews_test, labels_test))

# %% [markdown]
# * **Using the ``tf.data`` API, load in the training and validation data for the overviews.**

# %%
# CodeGrade Tag Ex1b-i
### Construct the training and validation datasets. Use a batch size of 64.

BATCH_SIZE = 64

overviews_train_ds = list_overviews_train_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

overviews_valid_ds = list_overviews_valid_ds.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# * Build the vocabulary of the model by calling the ``encoder.adapt()`` method on the film overviews train data.

# %%
# CodeGrade Tag Ex1b-ii
### Build the vocabulary of the model by calling the encoder.adapt() method on
### the film overviews train data.

VOCAB_SIZE = 10000

encoder = tf.keras.layers.TextVectorization(
    max_tokens=VOCAB_SIZE,
    output_mode='int',
    output_sequence_length=200
)

encoder.adapt(overviews_train)

# %% [markdown]
# * Print the first 200 words of the vocabulary you obtained.

# %%
# CodeGrade Tag Ex1b-iii
### Print the first 200 words of the vocabulary you obtained.

vocab = encoder.get_vocabulary()
print(vocab[:200])
# Out:
# ['', '[UNK]', np.str_('a'), np.str_('the'), np.str_('to'), np.str_('and'), np.str_('of'), np.str_('in'), np.str_('his'), np.str_('is'), np.str_('an'), np.str_('with'), np.str_('her'), np.str_('for'), np.str_('he'), np.str_('on'), np.str_('their'), np.str_('who'), np.str_('by'), np.str_('from'), np.str_('when'), np.str_('as'), np.str_('that'), np.str_('after'), np.str_('young'), np.str_('life'), np.str_('they'), np.str_('man'), np.str_('new'), np.str_('two'), np.str_('him'), np.str_('at'), np.str_('but'), np.str_('are'), np.str_('into'), np.str_('up'), np.str_('has'), np.str_('she'), np.str_('woman'), np.str_('out'), np.str_('love'), np.str_('family'), np.str_('one'), np.str_('must'), np.str_('find'), np.str_('be'), np.str_('friends'), np.str_('finds'), np.str_('it'), np.str_('story'), np.str_('world'), np.str_('school'), np.str_('them'), np.str_('about'), np.str_('where'), np.str_('while'), np.str_('group'), np.str_('father'), np.str_('have'), np.str_('girl'), np.str_('lives'), np.str_('years'), np.str_('wife'), np.str_('home'), np.str_('city'), np.str_('town'), np.str_('help'), np.str_('war'), np.str_('get'), np.str_('becomes'), np.str_('back'), np.str_('all'), np.str_('during'), np.str_('three'), np.str_('son'), np.str_('himself'), np.str_('boy'), np.str_('york'), np.str_('which'), np.str_('only'), np.str_('murder'), np.str_('against'), np.str_('high'), np.str_('time'), np.str_('daughter'), np.str_('gets'), np.str_('between'), np.str_('takes'), np.str_('mother'), np.str_('former'), np.str_('police'), np.str_('friend'), np.str_('team'), np.str_('small'), np.str_('other'), np.str_('being'), np.str_('falls'), np.str_('down'), np.str_('american'), np.str_('own'), np.str_('tries'), np.str_('before'), np.str_('will'), np.str_('this'), np.str_('save'), np.str_('become'), np.str_('death'), np.str_('can'), np.str_('agent'), np.str_('was'), np.str_('take'), np.str_('old'), np.str_('its'), np.str_('college'), np.str_('together'), np.str_('over'), np.str_('order'), np.str_('goes'), np.str_('go'), np.str_('husband'), np.str_('couple'), np.str_('through'), np.str_('relationship'), np.str_('killer'), np.str_('way'), np.str_('off'), np.str_('returns'), np.str_('meets'), np.str_('each'), np.str_('set'), np.str_('not'), np.str_('mysterious'), np.str_('people'), np.str_('best'), np.str_('work'), np.str_('more'), np.str_('brother'), np.str_('discovers'), np.str_('begins'), np.str_('now'), np.str_('job'), np.str_('stop'), np.str_('make'), np.str_('first'), np.str_('hes'), np.str_('secret'), np.str_('drug'), np.str_('what'), np.str_('living'), np.str_('us'), np.str_('forced'), np.str_('day'), np.str_('four'), np.str_('evil'), np.str_('trying'), np.str_('cop'), np.str_('turns'), np.str_('local'), np.str_('detective'), np.str_('comes'), np.str_('been'), np.str_('past'), np.str_('married'), np.str_('house'), np.str_('soon'), np.str_('just'), np.str_('men'), np.str_('whose'), np.str_('try'), np.str_('earth'), np.str_('student'), np.str_('some'), np.str_('or'), np.str_('officer'), np.str_('film'), np.str_('sent'), np.str_('parents'), np.str_('discover'), np.str_('prison'), np.str_('movie'), np.str_('brothers'), np.str_('battle'), np.str_('another'), np.str_('teenage'), np.str_('so'), np.str_('series'), np.str_('trip'), np.str_('run'), np.str_('most'), np.str_('killed'), np.str_('fight'), np.str_('black'), np.str_('true'), np.str_('than'), np.str_('sister'), np.str_('herself'), np.str_('car'), np.str_('accident'), np.str_('women'), np.str_('los')]

# %% [markdown]
# # 2. Definition of the models
#
# ### 2.a. CNN
#
# **Using the Keras Functional API, create a convolutional neural network with the architecture shown in the model summary below.**
#
# **A few important points to consider:**
#
# * Call the convolutional layers and the first dense layer should have ReLU activation functions. The output layer should have a Sigmoid activation function.
# * Pay attention to the output shapes and the number of partmeters for each layer, as these give indications as to the correct settings for the number of filters, kernel size, stride length and padding.
# * Use the layer names provided in the summary in your model.
# * For the dropout layers, use a dropout rate of 0.2 after the convolutional layers and 0.5 after the dense layers.

# %% [markdown]
# ```
# # Model Summary
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 64, 64, 3)]       0
#
#  Conv0 (Conv2D)              (None, 32, 32, 16)        448
#
#  Drop1 (Dropout)             (None, 32, 32, 16)        0
#
#  Conv1 (Conv2D)              (None, 32, 32, 32)        4640
#
#  Conv2 (Conv2D)              (None, 32, 32, 32)        9248
#
#  Drop2 (Dropout)             (None, 32, 32, 32)        0
#
#  Pool1 (MaxPooling2D)        (None, 16, 16, 32)        0
#
#  Conv3 (Conv2D)              (None, 16, 16, 64)        18496
#
#  Conv4 (Conv2D)              (None, 16, 16, 64)        36928
#
#  Drop3 (Dropout)             (None, 16, 16, 64)        0
#
#  Pool2 (MaxPooling2D)        (None, 8, 8, 64)          0
#
#  Conv5 (Conv2D)              (None, 8, 8, 128)         73856
#
#  Conv6 (Conv2D)              (None, 8, 8, 128)         147584
#
#  Drop4 (Dropout)             (None, 8, 8, 128)         0
#
#  Pool3 (MaxPooling2D)        (None, 4, 4, 128)         0
#
#  Flat (Flatten)              (None, 2048)              0
#
#  FC1 (Dense)                 (None, 1024)              2098176
#
#  Drop5 (Dropout)             (None, 1024)              0
#
#  FC2 (Dense)                 (None, 1024)              1049600
#
#  Drop6 (Dropout)             (None, 1024)              0
#
#  Output (Dense)              (None, 25)                25625
#
# =================================================================
# Total params: 3464601 (13.22 MB)
# Trainable params: 3464601 (13.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
#
#
# ```

# %%
# CodeGrade Tag Ex2a-i
### Define the model using the Keras Functional API. Use the summary above as a
### guide for the model parameters. You will need to define the filters/units of
### the layers correctly, as well as the kernel size, stride length and padding
### of the convolutional layers.

def build_cnn_model():
    inputs = Input(shape=(64, 64, 3), name='Input')

    x = Conv2D(16, kernel_size=3, strides=2, padding='same', activation='relu', name='Conv0')(inputs)
    x = Dropout(0.2, name='Drop1')(x)

    x = Conv2D(32, kernel_size=3, padding='same', activation='relu', name='Conv1')(x)
    x = Conv2D(32, kernel_size=3, padding='same', activation='relu', name='Conv2')(x)
    x = Dropout(0.2, name='Drop2')(x)
    x = MaxPooling2D(pool_size=2, name='Pool1')(x)

    x = Conv2D(64, kernel_size=3, padding='same', activation='relu', name='Conv3')(x)
    x = Conv2D(64, kernel_size=3, padding='same', activation='relu', name='Conv4')(x)
    x = Dropout(0.2, name='Drop3')(x)
    x = MaxPooling2D(pool_size=2, name='Pool2')(x)

    x = Conv2D(128, kernel_size=3, padding='same', activation='relu', name='Conv5')(x)
    x = Conv2D(128, kernel_size=3, padding='same', activation='relu', name='Conv6')(x)
    x = Dropout(0.2, name='Drop4')(x)
    x = MaxPooling2D(pool_size=2, name='Pool3')(x)

    x = Flatten(name='Flat')(x)
    x = Dense(1024, activation='relu', name='FC1')(x)
    x = Dropout(0.5, name='Drop5')(x)
    x = Dense(1024, activation='relu', name='FC2')(x)
    x = Dropout(0.5, name='Drop6')(x)
    outputs = Dense(25, activation='sigmoid', name='Output')(x)

    model = keras.Model(inputs=inputs, outputs=outputs, name='model')
    return model

cnn_model = build_cnn_model()

# %% [markdown]
# * Print the model summary and confirm it has the same architecture as the one provided.

# %%
# CodeGrade Tag Ex2a-ii
### Print the model summary and confirm it has the same architecture as the one
### provided.

cnn_model.summary()
# Out:
# Model: "model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ Input (InputLayer)              │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv0 (Conv2D)                  │ (None, 32, 32, 16)     │           448 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop1 (Dropout)                 │ (None, 32, 32, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv1 (Conv2D)                  │ (None, 32, 32, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv2 (Conv2D)                  │ (None, 32, 32, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop2 (Dropout)                 │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool1 (MaxPooling2D)            │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv3 (Conv2D)                  │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv4 (Conv2D)                  │ (None, 16, 16, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop3 (Dropout)                 │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool2 (MaxPooling2D)            │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv5 (Conv2D)                  │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Conv6 (Conv2D)                  │ (None, 8, 8, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop4 (Dropout)                 │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Pool3 (MaxPooling2D)            │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Flat (Flatten)                  │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FC1 (Dense)                     │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop5 (Dropout)                 │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ FC2 (Dense)                     │ (None, 1024)           │     1,049,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Drop6 (Dropout)                 │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ Output (Dense)                  │ (None, 25)             │        25,625 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,464,601 (13.22 MB)
#  Trainable params: 3,464,601 (13.22 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * **Compile the model using the Adam Optimizer with a learning rate of ```1e-4``` and ```binary crossentropy``` loss function. For the metrics, use the ``Precision`` and ``Recall`` functions.**

# %%
# CodeGrade Tag Ex2a-iii
### Compile the model using the Adam Optimizer with a learning rate of 1e-4 and
### binary crossentropy loss function. For the metrics, use the Precision and
### Recall functions.

cnn_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=[Precision(), Recall()]
)

# %% [markdown]
# ### 2.b. LSTM model
#
# * Set up the embedding layer by using ```tf.keras.layers.Embedding```. The ```input_dim``` is the length of the vocab, and the ```output_dim``` must be **265**. You should also set ```mask_zero=True```.

# %%
# CodeGrade Tag Ex2b-i
### Set up the embedding layer. The input_dim is the length of the vocab, and
### the output_dim must be 256. You should also set mask_zero=True.

embedder = tf.keras.layers.Embedding(
    input_dim=len(encoder.get_vocabulary()),
    output_dim=256,
    mask_zero=True
)

# %% [markdown]
# * Use ```tf.keras.Sequential``` to build a keras sequential model, with the following layers:
#
#
#
#   1.   encoder
#   2.   embedder
#   3.   biLSTM layer with 256 units, dropout 0.5, recurrent dropout 0.2 (make sure to use the right ```return_sequences``` parametre to be able to stack this layer with the following BiLSTM)
#   4.   biLSTM layer with 128 units, dropout 0.5, recurrent dropout 0.2
#   5.   dense layer with 128 units and relu activation function
#   6.   dropout with rate 0.8
#   7.   dense output layer with 25 units and sigmoid activation function

# %%
# CodeGrade Tag Ex2b-ii
### Build a keras sequential model, with the layers provided above.

lstm_model = tf.keras.Sequential([
    encoder,
    embedder,
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(256, dropout=0.5, recurrent_dropout=0.2, return_sequences=True)
    ),
    tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(128, dropout=0.5, recurrent_dropout=0.2)
    ),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.8),
    tf.keras.layers.Dense(25, activation='sigmoid')
])

lstm_model.build((None,))

# %% [markdown]
# * Print the model summary and confirm is has the same architecture as the outline provided above.

# %%
# CodeGrade Tag Ex2b-iii
### Print the model summary and confirm is has the same architecture as the
### outline provided above.

lstm_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ text_vectorization              │ (None, 200)            │             0 │
# │ (TextVectorization)             │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding (Embedding)           │ (None, 200, 256)       │     2,560,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ (None, 200, 512)       │     1,050,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ (None, 256)            │       656,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 25)             │         3,225 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,303,129 (16.42 MB)
#  Trainable params: 4,303,129 (16.42 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# * Compile the model with binary crossentropy loss and the adam optimizer. For the metrics, use the Precision and Recall functions.

# %%
# CodeGrade Tag Ex2b-iv
### Compile the model with binary crossentropy loss, the adam optimizer, with
### the precision and recall metrics

lstm_model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='binary_crossentropy',
    metrics=[Precision(), Recall()]
)

# %% [markdown]
# # 3. Training of the models
#
# * **For each model, create a Checkpoint Callback that saves the weights of the best performing epoch, based on the validation loss.**

# %%
# CodeGrade Tag Ex3a-i
### Create two ModelCheckpoint callbacks to store the bext weights from each
### model, both based on the validation loss.

checkpoint_cnn_filepath = '/content/checkpoint_cnn.weights.h5'
checkpoint_lstm_filepath = '/content/checkpoint_lstm.weights.h5'

from tensorflow.keras.callbacks import ModelCheckpoint

checkpoint_cnn_callback = ModelCheckpoint(
    filepath=checkpoint_cnn_filepath,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

checkpoint_lstm_callback = ModelCheckpoint(
    filepath=checkpoint_lstm_filepath,
    monitor='val_loss',
    save_best_only=True,
    save_weights_only=True,
    verbose=1
)

# %% [markdown]
# * **Create a Learning Rate Scheduler Callback that utilises the provided function to decrease the learning rate during training.**

# %%
# CodeGrade Tag Ex3a-ii
### Using the function provided, create a LearningRateScheduler callback, call
### it "lr_callback"

def scheduler(epoch, lr):
    if epoch < 10:
        return float(lr)
    else:
        return float(lr * tf.math.exp(-0.01))

from tensorflow.keras.callbacks import LearningRateScheduler

lr_callback = LearningRateScheduler(scheduler)

# %% [markdown]
# ### 3.a. CNN training
#
# * **Train the CNN model for 40 epochs, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3a-iii
### Train the model for 40 epochs, using the callbacks you have created. Store
### the losses and metrics in a history object.

cnn_history = cnn_model.fit(
    posters_train_ds,
    validation_data=posters_valid_ds,
    epochs=40,
    callbacks=[checkpoint_cnn_callback, lr_callback]
)
# Out:
# Epoch 1/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 674ms/step - loss: 0.4499 - precision: 0.2703 - recall: 0.2707
# Epoch 1: val_loss improved from inf to 0.32143, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 78s 747ms/step - loss: 0.4484 - precision: 0.2713 - recall: 0.2703 - val_loss: 0.3214 - val_precision: 0.5312 - val_recall: 0.2246 - learning_rate: 1.0000e-04
# Epoch 2/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 647ms/step - loss: 0.2573 - precision: 0.4823 - recall: 0.2170
# Epoch 2: val_loss improved from 0.32143 to 0.31138, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 55s 679ms/step - loss: 0.2572 - precision: 0.4824 - recall: 0.2171 - val_loss: 0.3114 - val_precision: 0.5312 - val_recall: 0.2246 - learning_rate: 1.0000e-04
# Epoch 3/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 649ms/step - loss: 0.2492 - precision: 0.5060 - recall: 0.2109
# Epoch 3: val_loss improved from 0.31138 to 0.29724, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 681ms/step - loss: 0.2491 - precision: 0.5062 - recall: 0.2110 - val_loss: 0.2972 - val_precision: 0.5732 - val_recall: 0.3128 - learning_rate: 1.0000e-04
# Epoch 4/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 655ms/step - loss: 0.2398 - precision: 0.5471 - recall: 0.2417
# Epoch 4: val_loss improved from 0.29724 to 0.28603, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 55s 689ms/step - loss: 0.2398 - precision: 0.5472 - recall: 0.2419 - val_loss: 0.2860 - val_precision: 0.5688 - val_recall: 0.3369 - learning_rate: 1.0000e-04
# Epoch 5/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 658ms/step - loss: 0.2369 - precision: 0.5540 - recall: 0.2574
# Epoch 5: val_loss improved from 0.28603 to 0.27808, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 55s 691ms/step - loss: 0.2369 - precision: 0.5541 - recall: 0.2575 - val_loss: 0.2781 - val_precision: 0.5733 - val_recall: 0.3202 - learning_rate: 1.0000e-04
# Epoch 6/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 648ms/step - loss: 0.2331 - precision: 0.5645 - recall: 0.2757
# Epoch 6: val_loss improved from 0.27808 to 0.27235, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 55s 690ms/step - loss: 0.2331 - precision: 0.5645 - recall: 0.2756 - val_loss: 0.2724 - val_precision: 0.5670 - val_recall: 0.2871 - learning_rate: 1.0000e-04
# Epoch 7/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 640ms/step - loss: 0.2315 - precision: 0.5749 - recall: 0.2719
# Epoch 7: val_loss improved from 0.27235 to 0.27154, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 56s 707ms/step - loss: 0.2315 - precision: 0.5748 - recall: 0.2718 - val_loss: 0.2715 - val_precision: 0.5761 - val_recall: 0.3212 - learning_rate: 1.0000e-04
# Epoch 8/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 630ms/step - loss: 0.2317 - precision: 0.5839 - recall: 0.2801
# Epoch 8: val_loss improved from 0.27154 to 0.26380, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 56s 697ms/step - loss: 0.2317 - precision: 0.5838 - recall: 0.2801 - val_loss: 0.2638 - val_precision: 0.5564 - val_recall: 0.2604 - learning_rate: 1.0000e-04
# Epoch 9/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 632ms/step - loss: 0.2299 - precision: 0.5832 - recall: 0.2729
# Epoch 9: val_loss improved from 0.26380 to 0.26085, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 56s 699ms/step - loss: 0.2299 - precision: 0.5831 - recall: 0.2729 - val_loss: 0.2609 - val_precision: 0.5927 - val_recall: 0.2884 - learning_rate: 1.0000e-04
# Epoch 10/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 632ms/step - loss: 0.2298 - precision: 0.5816 - recall: 0.2659
# Epoch 10: val_loss improved from 0.26085 to 0.25761, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 56s 698ms/step - loss: 0.2298 - precision: 0.5816 - recall: 0.2660 - val_loss: 0.2576 - val_precision: 0.5327 - val_recall: 0.2259 - learning_rate: 1.0000e-04
# Epoch 11/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - loss: 0.2269 - precision: 0.5863 - recall: 0.2788
# Epoch 11: val_loss improved from 0.25761 to 0.25371, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 701ms/step - loss: 0.2269 - precision: 0.5863 - recall: 0.2788 - val_loss: 0.2537 - val_precision: 0.5360 - val_recall: 0.2263 - learning_rate: 9.9005e-05
# Epoch 12/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - loss: 0.2265 - precision: 0.6004 - recall: 0.2839
# Epoch 12: val_loss did not improve from 0.25371
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 56s 699ms/step - loss: 0.2265 - precision: 0.6004 - recall: 0.2839 - val_loss: 0.2577 - val_precision: 0.5428 - val_recall: 0.2099 - learning_rate: 9.8020e-05
# Epoch 13/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - loss: 0.2279 - precision: 0.5941 - recall: 0.2586
# Epoch 13: val_loss improved from 0.25371 to 0.24954, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 56s 702ms/step - loss: 0.2279 - precision: 0.5942 - recall: 0.2588 - val_loss: 0.2495 - val_precision: 0.5435 - val_recall: 0.2256 - learning_rate: 9.7045e-05
# Epoch 14/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - loss: 0.2268 - precision: 0.6165 - recall: 0.2803
# Epoch 14: val_loss did not improve from 0.24954
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 698ms/step - loss: 0.2268 - precision: 0.6164 - recall: 0.2803 - val_loss: 0.2520 - val_precision: 0.5494 - val_recall: 0.2266 - learning_rate: 9.6079e-05
# Epoch 15/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - loss: 0.2248 - precision: 0.6075 - recall: 0.2891
# Epoch 15: val_loss did not improve from 0.24954
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 56s 698ms/step - loss: 0.2248 - precision: 0.6075 - recall: 0.2891 - val_loss: 0.2524 - val_precision: 0.5899 - val_recall: 0.2346 - learning_rate: 9.5123e-05
# Epoch 16/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - loss: 0.2256 - precision: 0.6088 - recall: 0.2711
# Epoch 16: val_loss improved from 0.24954 to 0.24877, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 56s 700ms/step - loss: 0.2256 - precision: 0.6089 - recall: 0.2712 - val_loss: 0.2488 - val_precision: 0.5650 - val_recall: 0.2323 - learning_rate: 9.4176e-05
# Epoch 17/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - loss: 0.2234 - precision: 0.6323 - recall: 0.2838
# Epoch 17: val_loss did not improve from 0.24877
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 56s 699ms/step - loss: 0.2234 - precision: 0.6322 - recall: 0.2837 - val_loss: 0.2530 - val_precision: 0.6101 - val_recall: 0.2463 - learning_rate: 9.3239e-05
# Epoch 18/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 631ms/step - loss: 0.2238 - precision: 0.6195 - recall: 0.2827
# Epoch 18: val_loss improved from 0.24877 to 0.24718, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 53s 669ms/step - loss: 0.2238 - precision: 0.6195 - recall: 0.2827 - val_loss: 0.2472 - val_precision: 0.5741 - val_recall: 0.2356 - learning_rate: 9.2312e-05
# Epoch 19/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 644ms/step - loss: 0.2226 - precision: 0.6316 - recall: 0.2829
# Epoch 19: val_loss improved from 0.24718 to 0.24653, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 55s 678ms/step - loss: 0.2226 - precision: 0.6316 - recall: 0.2829 - val_loss: 0.2465 - val_precision: 0.5918 - val_recall: 0.2617 - learning_rate: 9.1393e-05
# Epoch 20/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 654ms/step - loss: 0.2213 - precision: 0.6261 - recall: 0.2757
# Epoch 20: val_loss improved from 0.24653 to 0.24164, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 55s 686ms/step - loss: 0.2213 - precision: 0.6262 - recall: 0.2757 - val_loss: 0.2416 - val_precision: 0.5775 - val_recall: 0.2390 - learning_rate: 9.0484e-05
# Epoch 21/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 655ms/step - loss: 0.2235 - precision: 0.6237 - recall: 0.2846
# Epoch 21: val_loss did not improve from 0.24164
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 55s 686ms/step - loss: 0.2234 - precision: 0.6238 - recall: 0.2846 - val_loss: 0.2463 - val_precision: 0.5712 - val_recall: 0.2279 - learning_rate: 8.9583e-05
# Epoch 22/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 645ms/step - loss: 0.2220 - precision: 0.6489 - recall: 0.2790
# Epoch 22: val_loss improved from 0.24164 to 0.24025, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 55s 687ms/step - loss: 0.2220 - precision: 0.6489 - recall: 0.2790 - val_loss: 0.2402 - val_precision: 0.5787 - val_recall: 0.2410 - learning_rate: 8.8692e-05
# Epoch 23/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - loss: 0.2194 - precision: 0.6459 - recall: 0.2826
# Epoch 23: val_loss did not improve from 0.24025
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 56s 698ms/step - loss: 0.2194 - precision: 0.6459 - recall: 0.2826 - val_loss: 0.2425 - val_precision: 0.5749 - val_recall: 0.2346 - learning_rate: 8.7810e-05
# Epoch 24/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - loss: 0.2183 - precision: 0.6509 - recall: 0.2866
# Epoch 24: val_loss did not improve from 0.24025
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 56s 698ms/step - loss: 0.2183 - precision: 0.6508 - recall: 0.2865 - val_loss: 0.2419 - val_precision: 0.5787 - val_recall: 0.2126 - learning_rate: 8.6936e-05
# Epoch 25/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - loss: 0.2177 - precision: 0.6462 - recall: 0.2804
# Epoch 25: val_loss did not improve from 0.24025
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 698ms/step - loss: 0.2177 - precision: 0.6463 - recall: 0.2804 - val_loss: 0.2414 - val_precision: 0.5860 - val_recall: 0.2426 - learning_rate: 8.6071e-05
# Epoch 26/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - loss: 0.2177 - precision: 0.6519 - recall: 0.2908
# Epoch 26: val_loss did not improve from 0.24025
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 698ms/step - loss: 0.2177 - precision: 0.6519 - recall: 0.2908 - val_loss: 0.2465 - val_precision: 0.6003 - val_recall: 0.2430 - learning_rate: 8.5214e-05
# Epoch 27/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - loss: 0.2194 - precision: 0.6591 - recall: 0.2942
# Epoch 27: val_loss improved from 0.24025 to 0.23834, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 56s 700ms/step - loss: 0.2194 - precision: 0.6590 - recall: 0.2941 - val_loss: 0.2383 - val_precision: 0.6043 - val_recall: 0.2343 - learning_rate: 8.4366e-05
# Epoch 28/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - loss: 0.2167 - precision: 0.6585 - recall: 0.2828
# Epoch 28: val_loss did not improve from 0.23834
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 56s 700ms/step - loss: 0.2167 - precision: 0.6584 - recall: 0.2828 - val_loss: 0.2412 - val_precision: 0.6106 - val_recall: 0.2186 - learning_rate: 8.3527e-05
# Epoch 29/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 636ms/step - loss: 0.2157 - precision: 0.6556 - recall: 0.2762
# Epoch 29: val_loss did not improve from 0.23834
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 81s 689ms/step - loss: 0.2157 - precision: 0.6556 - recall: 0.2762 - val_loss: 0.2425 - val_precision: 0.5764 - val_recall: 0.2470 - learning_rate: 8.2696e-05
# Epoch 30/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - loss: 0.2146 - precision: 0.6446 - recall: 0.2873
# Epoch 30: val_loss did not improve from 0.23834
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 53s 664ms/step - loss: 0.2147 - precision: 0.6446 - recall: 0.2873 - val_loss: 0.2415 - val_precision: 0.6067 - val_recall: 0.2527 - learning_rate: 8.1873e-05
# Epoch 31/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 652ms/step - loss: 0.2150 - precision: 0.6730 - recall: 0.2872
# Epoch 31: val_loss improved from 0.23834 to 0.23654, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 55s 685ms/step - loss: 0.2150 - precision: 0.6728 - recall: 0.2872 - val_loss: 0.2365 - val_precision: 0.6268 - val_recall: 0.2503 - learning_rate: 8.1058e-05
# Epoch 32/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 654ms/step - loss: 0.2161 - precision: 0.6666 - recall: 0.2864
# Epoch 32: val_loss did not improve from 0.23654
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 55s 685ms/step - loss: 0.2161 - precision: 0.6666 - recall: 0.2864 - val_loss: 0.2447 - val_precision: 0.5668 - val_recall: 0.2326 - learning_rate: 8.0252e-05
# Epoch 33/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 659ms/step - loss: 0.2164 - precision: 0.6647 - recall: 0.2854
# Epoch 33: val_loss did not improve from 0.23654
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 55s 689ms/step - loss: 0.2164 - precision: 0.6646 - recall: 0.2854 - val_loss: 0.2430 - val_precision: 0.5858 - val_recall: 0.2406 - learning_rate: 7.9453e-05
# Epoch 34/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 659ms/step - loss: 0.2162 - precision: 0.6577 - recall: 0.2881
# Epoch 34: val_loss improved from 0.23654 to 0.23306, saving model to /content/checkpoint_cnn.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 693ms/step - loss: 0.2162 - precision: 0.6577 - recall: 0.2881 - val_loss: 0.2331 - val_precision: 0.6372 - val_recall: 0.2624 - learning_rate: 7.8663e-05
# Epoch 35/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 658ms/step - loss: 0.2154 - precision: 0.6588 - recall: 0.2930
# Epoch 35: val_loss did not improve from 0.23306
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 688ms/step - loss: 0.2154 - precision: 0.6589 - recall: 0.2930 - val_loss: 0.2336 - val_precision: 0.6247 - val_recall: 0.2553 - learning_rate: 7.7880e-05
# Epoch 36/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 636ms/step - loss: 0.2167 - precision: 0.6559 - recall: 0.2889
# Epoch 36: val_loss did not improve from 0.23306
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 56s 701ms/step - loss: 0.2167 - precision: 0.6559 - recall: 0.2889 - val_loss: 0.2384 - val_precision: 0.6002 - val_recall: 0.2283 - learning_rate: 7.7105e-05
# Epoch 37/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 636ms/step - loss: 0.2118 - precision: 0.6651 - recall: 0.2889
# Epoch 37: val_loss did not improve from 0.23306
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 56s 701ms/step - loss: 0.2118 - precision: 0.6651 - recall: 0.2889 - val_loss: 0.2385 - val_precision: 0.5966 - val_recall: 0.2363 - learning_rate: 7.6338e-05
# Epoch 38/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - loss: 0.2144 - precision: 0.6712 - recall: 0.2890
# Epoch 38: val_loss did not improve from 0.23306
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 82s 700ms/step - loss: 0.2144 - precision: 0.6712 - recall: 0.2891 - val_loss: 0.2381 - val_precision: 0.5876 - val_recall: 0.2366 - learning_rate: 7.5578e-05
# Epoch 39/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 636ms/step - loss: 0.2123 - precision: 0.6720 - recall: 0.2866
# Epoch 39: val_loss did not improve from 0.23306
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 81s 688ms/step - loss: 0.2123 - precision: 0.6720 - recall: 0.2867 - val_loss: 0.2347 - val_precision: 0.6198 - val_recall: 0.2490 - learning_rate: 7.4826e-05
# Epoch 40/40
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - loss: 0.2121 - precision: 0.6787 - recall: 0.2942
# Epoch 40: val_loss did not improve from 0.23306
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 56s 702ms/step - loss: 0.2121 - precision: 0.6786 - recall: 0.2943 - val_loss: 0.2408 - val_precision: 0.6279 - val_recall: 0.2239 - learning_rate: 7.4082e-05

# %% [markdown]
# * **Train the model for 20 epochs** (this may take several minutes)**, using the callbacks you made previously. Store the losses and metrics to use later.**

# %%
# CodeGrade Tag Ex3b-i
# Train the model for 20 epochs.
lstm_history = lstm_model.fit(
    overviews_train_ds,
    validation_data=overviews_valid_ds,
    epochs=20,
    callbacks=[checkpoint_lstm_callback, lr_callback]
)
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.6649 - precision_1: 0.1077 - recall_1: 0.3837
# Epoch 1: val_loss improved from inf to 0.37385, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 648s 8s/step - loss: 0.6643 - precision_1: 0.1079 - recall_1: 0.3832 - val_loss: 0.3739 - val_precision_1: 0.5301 - val_recall_1: 0.0795 - learning_rate: 1.0000e-04
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.4839 - precision_1: 0.1590 - recall_1: 0.2940
# Epoch 2: val_loss improved from 0.37385 to 0.30291, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 629s 8s/step - loss: 0.4837 - precision_1: 0.1591 - recall_1: 0.2939 - val_loss: 0.3029 - val_precision_1: 0.5000 - val_recall_1: 6.6845e-04 - learning_rate: 1.0000e-04
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.4280 - precision_1: 0.1908 - recall_1: 0.2712
# Epoch 3: val_loss improved from 0.30291 to 0.27825, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 675s 8s/step - loss: 0.4279 - precision_1: 0.1909 - recall_1: 0.2710 - val_loss: 0.2782 - val_precision_1: 0.7857 - val_recall_1: 0.0037 - learning_rate: 1.0000e-04
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.3850 - precision_1: 0.2331 - recall_1: 0.2536
# Epoch 4: val_loss improved from 0.27825 to 0.26099, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 620s 8s/step - loss: 0.3849 - precision_1: 0.2331 - recall_1: 0.2535 - val_loss: 0.2610 - val_precision_1: 0.5532 - val_recall_1: 0.2015 - learning_rate: 1.0000e-04
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.3618 - precision_1: 0.2635 - recall_1: 0.2478
# Epoch 5: val_loss improved from 0.26099 to 0.25296, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 621s 8s/step - loss: 0.3617 - precision_1: 0.2637 - recall_1: 0.2478 - val_loss: 0.2530 - val_precision_1: 0.5337 - val_recall_1: 0.2223 - learning_rate: 1.0000e-04
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.3413 - precision_1: 0.2984 - recall_1: 0.2379
# Epoch 6: val_loss improved from 0.25296 to 0.24778, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 629s 8s/step - loss: 0.3413 - precision_1: 0.2985 - recall_1: 0.2378 - val_loss: 0.2478 - val_precision_1: 0.5312 - val_recall_1: 0.2246 - learning_rate: 1.0000e-04
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.3249 - precision_1: 0.3248 - recall_1: 0.2350
# Epoch 7: val_loss improved from 0.24778 to 0.24419, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 614s 8s/step - loss: 0.3249 - precision_1: 0.3249 - recall_1: 0.2349 - val_loss: 0.2442 - val_precision_1: 0.5312 - val_recall_1: 0.2246 - learning_rate: 1.0000e-04
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.3163 - precision_1: 0.3485 - recall_1: 0.2326
# Epoch 8: val_loss improved from 0.24419 to 0.24213, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 621s 8s/step - loss: 0.3162 - precision_1: 0.3486 - recall_1: 0.2325 - val_loss: 0.2421 - val_precision_1: 0.5312 - val_recall_1: 0.2246 - learning_rate: 1.0000e-04
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.3085 - precision_1: 0.3593 - recall_1: 0.2235
# Epoch 9: val_loss improved from 0.24213 to 0.24026, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 633s 8s/step - loss: 0.3085 - precision_1: 0.3593 - recall_1: 0.2235 - val_loss: 0.2403 - val_precision_1: 0.5312 - val_recall_1: 0.2246 - learning_rate: 1.0000e-04
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.2992 - precision_1: 0.3791 - recall_1: 0.2200
# Epoch 10: val_loss improved from 0.24026 to 0.23810, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 686s 8s/step - loss: 0.2992 - precision_1: 0.3792 - recall_1: 0.2201 - val_loss: 0.2381 - val_precision_1: 0.5361 - val_recall_1: 0.2233 - learning_rate: 1.0000e-04
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.2914 - precision_1: 0.4045 - recall_1: 0.2259
# Epoch 11: val_loss improved from 0.23810 to 0.23617, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 673s 8s/step - loss: 0.2914 - precision_1: 0.4045 - recall_1: 0.2259 - val_loss: 0.2362 - val_precision_1: 0.5539 - val_recall_1: 0.2199 - learning_rate: 9.9005e-05
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.2871 - precision_1: 0.4301 - recall_1: 0.2307
# Epoch 12: val_loss improved from 0.23617 to 0.23358, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 616s 8s/step - loss: 0.2871 - precision_1: 0.4300 - recall_1: 0.2307 - val_loss: 0.2336 - val_precision_1: 0.5660 - val_recall_1: 0.2106 - learning_rate: 9.8020e-05
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.2800 - precision_1: 0.4329 - recall_1: 0.2331
# Epoch 13: val_loss improved from 0.23358 to 0.23065, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 618s 8s/step - loss: 0.2799 - precision_1: 0.4331 - recall_1: 0.2332 - val_loss: 0.2306 - val_precision_1: 0.6043 - val_recall_1: 0.1781 - learning_rate: 9.7045e-05
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.2720 - precision_1: 0.4650 - recall_1: 0.2530
# Epoch 14: val_loss improved from 0.23065 to 0.22882, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 618s 8s/step - loss: 0.2720 - precision_1: 0.4650 - recall_1: 0.2530 - val_loss: 0.2288 - val_precision_1: 0.6043 - val_recall_1: 0.2159 - learning_rate: 9.6079e-05
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.2678 - precision_1: 0.4935 - recall_1: 0.2548
# Epoch 15: val_loss improved from 0.22882 to 0.22713, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 623s 8s/step - loss: 0.2678 - precision_1: 0.4935 - recall_1: 0.2548 - val_loss: 0.2271 - val_precision_1: 0.6091 - val_recall_1: 0.2286 - learning_rate: 9.5123e-05
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.2669 - precision_1: 0.4811 - recall_1: 0.2553
# Epoch 16: val_loss did not improve from 0.22713
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 628s 8s/step - loss: 0.2669 - precision_1: 0.4812 - recall_1: 0.2553 - val_loss: 0.2273 - val_precision_1: 0.5933 - val_recall_1: 0.2794 - learning_rate: 9.4176e-05
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.2598 - precision_1: 0.5116 - recall_1: 0.2710
# Epoch 17: val_loss improved from 0.22713 to 0.22449, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 619s 8s/step - loss: 0.2598 - precision_1: 0.5116 - recall_1: 0.2710 - val_loss: 0.2245 - val_precision_1: 0.6024 - val_recall_1: 0.2517 - learning_rate: 9.3239e-05
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.2564 - precision_1: 0.5052 - recall_1: 0.2610
# Epoch 18: val_loss did not improve from 0.22449
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 628s 8s/step - loss: 0.2563 - precision_1: 0.5054 - recall_1: 0.2611 - val_loss: 0.2253 - val_precision_1: 0.5922 - val_recall_1: 0.2791 - learning_rate: 9.2312e-05
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.2513 - precision_1: 0.5489 - recall_1: 0.2847
# Epoch 19: val_loss improved from 0.22449 to 0.22312, saving model to /content/checkpoint_lstm.weights.h5
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 622s 8s/step - loss: 0.2513 - precision_1: 0.5488 - recall_1: 0.2847 - val_loss: 0.2231 - val_precision_1: 0.6056 - val_recall_1: 0.2664 - learning_rate: 9.1393e-05
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 7s/step - loss: 0.2491 - precision_1: 0.5410 - recall_1: 0.2847
# Epoch 20: val_loss did not improve from 0.22312
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 683s 8s/step - loss: 0.2491 - precision_1: 0.5411 - recall_1: 0.2848 - val_loss: 0.2232 - val_precision_1: 0.6097 - val_recall_1: 0.2777 - learning_rate: 9.0484e-05

# %% [markdown]
# # 4. Evaluation of the models
#
# ### 4.a. CNN Evaluation
#
# * **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the model performance.**

# %%
# CodeGrade Tag Ex4a-i

import matplotlib.pyplot as plt

def plot_cnn_history(history):
    metrics = ['loss', 'precision', 'recall']
    colors = {
        'loss': ('green', 'red'),
        'precision': ('green', 'red'),
        'recall': ('green', 'red')
    }

    for metric in metrics:
        train_color, val_color = colors[metric]
        plt.figure(figsize=(8, 4))
        plt.plot(history.history[metric], label=f'Training {metric.title()}', color=train_color, linestyle='-', linewidth=2)
        plt.plot(history.history[f'val_{metric}'], label=f'Validation {metric.title()}', color=val_color, linestyle='--', linewidth=2)
        plt.xlabel("Epochs", fontsize=12)
        plt.ylabel(metric.title(), fontsize=12)
        plt.title(f'CNN Model {metric.title()} Over Epochs', fontsize=14, fontweight='bold')
        plt.legend()
        plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
        plt.tight_layout()
        plt.show()

# Call the function using your trained CNN model history object
plot_cnn_history(cnn_history)

# %% [markdown]
# * **Load the best weights from your model checkpoint, and create plots demonstrating the classification performance for all three classes. Include these plots in your report, and critically evaluate on the performance of the model across the classes.**

# %% [markdown]
# ### 4.b. LSTM Evaluation
#
# * **Create plots using the losses and metrics. In your report, discuss these results and critically evaluate the model performance.**

# %%
# CodeGrade Tag Ex4b-i

import matplotlib.pyplot as plt

def plot_lstm_history(history):
    # Safely check what metrics are available
    available_metrics = [key.replace('val_', '') for key in history.history if not key.startswith('val_')]
    available_metrics = list(set(available_metrics) & {'loss', 'precision', 'recall', 'accuracy'})

    for metric in available_metrics:
        val_key = f'val_{metric}'
        plt.figure(figsize=(8, 4))
        plt.plot(history.history[metric], label=f'Training {metric.title()}', color='green', linestyle='-', linewidth=2)
        if val_key in history.history:
            plt.plot(history.history[val_key], label=f'Validation {metric.title()}', color='red', linestyle='--', linewidth=2)
        plt.xlabel("Epochs", fontsize=12)
        plt.ylabel(metric.title(), fontsize=12)
        plt.title(f'LSTM Model {metric.title()} Over Epochs', fontsize=14, fontweight='bold')
        plt.legend()
        plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
        plt.tight_layout()
        plt.show()

# Call this with your trained LSTM model history
plot_lstm_history(lstm_history)

# %% [markdown]
# ### 4.c. Produce examples for the report
#
# * First, load the best weights from your checkpoints of both your models.
#
# * Choose a few films from the dataset, plot their posters and print their overviews. Use these example films to demonstrate the classification performance of the CNN model on their posters and of the LSTM model on their overview.
#
# * Be sure to demonstrate the results of the multi-label classification. Compare, for each example film, the top three most probable genres predicted by the CNN and the top three most probable genres predicted by the LSTM with the ground truth genres.
#
# * Include these examples in your report, and critically evaluate on the performance of the model across the classes.

# %%
# CodeGrade Tag Ex4c

import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing import image

# Load best model weights from checkpoints
cnn_model.load_weights(checkpoint_cnn_filepath)
lstm_model.load_weights(checkpoint_lstm_filepath)

# Define number of examples to show
example_indices = [0, 1, 2]  # Replace or extend with different indices as needed

for idx in example_indices:
    print(f"\n============================ Example {idx + 1} ============================\n")

    # --- CNN Poster Prediction ---
    img_path = img_locs_test[0][idx]
    img_raw = tf.io.read_file(img_path)
    img_decoded = tf.image.decode_jpeg(img_raw, channels=3)
    img_resized = tf.image.resize(tf.image.convert_image_dtype(img_decoded, tf.float32), [64, 64])
    img_batch = tf.expand_dims(img_resized, axis=0)

    cnn_pred = cnn_model.predict(img_batch)[0]
    cnn_top3 = np.argsort(cnn_pred)[-3:][::-1]

    # --- LSTM Text Prediction ---
    overview_text = overviews_test[idx]
    overview_batch = tf.expand_dims(overview_text, axis=0)
    lstm_pred = lstm_model.predict(overview_batch)[0]
    lstm_top3 = np.argsort(lstm_pred)[-3:][::-1]

    # --- Ground Truth Labels ---
    true_indices = np.where(labels_test[idx] == 1)[0]

    # --- Display Overview ---
    print(" Overview:\n", overview_text)

    # --- Display Ground Truth Genres ---
    print("\n Ground Truth Genres:")
    for i in true_indices:
        print(f"• {genres[i]}")

    # --- Display CNN Predictions ---
    print("\n Top 3 CNN Poster Predictions:")
    for i in cnn_top3:
        print(f"• {genres[i]} ({cnn_pred[i]:.2f})")

    # --- Display LSTM Predictions ---
    print("\n Top 3 LSTM Text Predictions:")
    for i in lstm_top3:
        print(f"• {genres[i]} ({lstm_pred[i]:.2f})")

    # --- Display Poster Image ---
    plt.figure(figsize=(4, 4))
    plt.imshow(img_decoded.numpy())
    plt.title(" Poster Image", fontsize=12)
    plt.axis("off")
    plt.tight_layout()
    plt.show()
# Out:
# ============================ Example 1 ============================
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
#  Overview:
#  A couple with jobs and apartment in NYC, decide to move to his mom's farm, get married and have the baby there. They can also make the changes to get a better price for the farm. However, there's something seriously wrong with his mom.
#
#  Ground Truth Genres:
# • Drama
# • Thriller
#
#  Top 3 CNN Poster Predictions:
# • Drama (0.67)
# • Action (0.35)
# • Thriller (0.29)
#
#  Top 3 LSTM Text Predictions:
# • Drama (0.64)
# • Comedy (0.46)
# • Romance (0.21)
# ============================ Example 2 ============================
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 927ms/step
#  Overview:
#  After being shot, a lawyer loses his memory and must relearn speech and mobility, but he has a loving family to support him.
#
#  Ground Truth Genres:
# • Drama
#
#  Top 3 CNN Poster Predictions:
# • Drama (0.59)
# • Action (0.38)
# • Comedy (0.35)
#
#  Top 3 LSTM Text Predictions:
# • Drama (0.51)
# • Comedy (0.44)
# • Crime (0.19)
# ============================ Example 3 ============================
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 942ms/step
#  Overview:
#  A young man from Harlem, forced to cope with the 1980s drug scene, builds an illegal empire, only to have a crisis of conscience.
#
#  Ground Truth Genres:
# • Action
# • Crime
# • Drama
#
#  Top 3 CNN Poster Predictions:
# • Drama (0.67)
# • Action (0.33)
# • Thriller (0.33)
#
#  Top 3 LSTM Text Predictions:
# • Drama (0.63)
# • Comedy (0.52)
# • Romance (0.20)
